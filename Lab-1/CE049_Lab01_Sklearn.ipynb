# %% [markdown]
# Name: Gopani Kenil G. Roll No: CE049 ID: 19CEUOS080 @scikit learn Library

# %% [markdown]
# #Import the relevant libraries and read the dataset

# %%
import numpy as np

import matplotlib as plt

from sklearn import datasets #various toy datasets 

from sklearn import metrics #Check accuracy of model 

from sklearn.linear_model import LogisticRegression #various supervised and unsupervised learning algorithms

# %% [markdown]
# Dataset Loading

# %%
wine = datasets.load_wine()    #wine data set

# %% [markdown]
# Features− The variables of data are called its features. They are also known as predictors, inputs or attributes.
#
# Feature matrix − It is the collection of features, in case there are more than one.
#
# Feature Names − It is the list of all the names of the features.
#
# Response − It is the output variable that basically depends upon the feature variables. They are also known as target, label or output.
#
# Response Vector − It is used to represent response column. Generally, we have just one response column.
#
# Target Names− It represent the possible values taken by a response vector.

# %%
x = wine.data
y= wine.target

feature_names = wine.feature_names
target_names = wine.target_names
print("Feature names:", feature_names)
print("Target names:", target_names)
print("\nFirst 10 rows of X:\n", x[:10])
# Out:
# Feature names: ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Target names: ['class_0' 'class_1' 'class_2']
#
# First 10 rows of X:
#  [[1.423e+01 1.710e+00 2.430e+00 1.560e+01 1.270e+02 2.800e+00 3.060e+00
#   2.800e-01 2.290e+00 5.640e+00 1.040e+00 3.920e+00 1.065e+03]
#  [1.320e+01 1.780e+00 2.140e+00 1.120e+01 1.000e+02 2.650e+00 2.760e+00
#   2.600e-01 1.280e+00 4.380e+00 1.050e+00 3.400e+00 1.050e+03]
#  [1.316e+01 2.360e+00 2.670e+00 1.860e+01 1.010e+02 2.800e+00 3.240e+00
#   3.000e-01 2.810e+00 5.680e+00 1.030e+00 3.170e+00 1.185e+03]
#  [1.437e+01 1.950e+00 2.500e+00 1.680e+01 1.130e+02 3.850e+00 3.490e+00
#   2.400e-01 2.180e+00 7.800e+00 8.600e-01 3.450e+00 1.480e+03]
#  [1.324e+01 2.590e+00 2.870e+00 2.100e+01 1.180e+02 2.800e+00 2.690e+00
#   3.900e-01 1.820e+00 4.320e+00 1.040e+00 2.930e+00 7.350e+02]
# ...

# %%
from sklearn.model_selection import train_test_split    #import module for seprate trainning and testing data from original dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state=1)
print("x_train - trainning data :- ",x_train,sep='\n')
print("","x_test - testing data :- ",x_test,sep='\n')
print("","y_train - trainning data :- ",y_train,sep='\n')
print("","y_test - testing data :- ",y_test,sep='\n')
# Out:
# x_train - trainning data :-
# [[1.305e+01 1.770e+00 2.100e+00 ... 8.800e-01 3.350e+00 8.850e+02]
#  [1.233e+01 9.900e-01 1.950e+00 ... 1.060e+00 2.310e+00 7.500e+02]
#  [1.376e+01 1.530e+00 2.700e+00 ... 1.250e+00 3.000e+00 1.235e+03]
#  ...
#  [1.349e+01 1.660e+00 2.240e+00 ... 9.800e-01 2.780e+00 4.720e+02]
#  [1.293e+01 2.810e+00 2.700e+00 ... 7.700e-01 2.310e+00 6.000e+02]
#  [1.305e+01 1.650e+00 2.550e+00 ... 1.120e+00 2.510e+00 1.105e+03]]
#
# x_test - testing data :-
# [[1.369e+01 3.260e+00 2.540e+00 2.000e+01 1.070e+02 1.830e+00 5.600e-01
#   5.000e-01 8.000e-01 5.880e+00 9.600e-01 1.820e+00 6.800e+02]
#  [1.242e+01 1.610e+00 2.190e+00 2.250e+01 1.080e+02 2.000e+00 2.090e+00
#   3.400e-01 1.610e+00 2.060e+00 1.060e+00 2.960e+00 3.450e+02]
#  [1.364e+01 3.100e+00 2.560e+00 1.520e+01 1.160e+02 2.700e+00 3.030e+00
#   1.700e-01 1.660e+00 5.100e+00 9.600e-01 3.360e+00 8.450e+02]
#  [1.221e+01 1.190e+00 1.750e+00 1.680e+01 1.510e+02 1.850e+00 1.280e+00
# ...
